# %% [markdown]
# <h1>Soal 1: Pemahaman Machine Learning</h1>
#
# Jawab/Kerjakan pertanyaan/perintah di bawah ini dengan bahasa kalian sendiri:
#
# - Apa itu machine learning?
# - Apa itu data feature dan data target?
# - Apa Perbedaan Supervised Learning dan Unsupervised Learning?
# - Apa Jenis2 yang ada di dalam Supervised Learning? Jelaskan Perbedaannya!
# - Apa perbedaan Hyperparameter dan Parameter?
# - Sebutkan Langkah-langkah dalam mengaplikasikan algoritma apapun dalam machine learning!

# %% [raw]
# Jawaban:
# 1. Machine learning adalah metode yang dimiliki komputer untuk dapat belajar dari tugas-tugas sebelumnya
# 2. Data feature adalah variabel yang memprediksi suatu kejadian sedangkan data target adalah hasil dari prediksi
# 3. Supervised learning memiliki output yang jelas, sedangkan unsupervised learning tidak memiliki output yang jelas
# 4. Supervised learning dibagi jadi 2 yaitu classification dan regression. Kalau classification data terbagi menjadi beberapa kelompok tertentu, sedangkan regression data akan diprediksi secara kontinu
# 5. Hyperparameter didefinisikan di awal pembuatan model dan tidak ada sangkut pautnya dengan model, sedangkan parameter pembuatan objek dihasilkan di akhir dan terdapat sangkut pautnya dengan model
# 6. Langkah-langkah ML yang pertama menentukan model dari algoritma yang ingin digunakan, lalu yang kedua menentukan hyperparameter untuk model yang sudah ditentukan, lalu membagi data menjadi data feature dan data target, selanjutnya melakukan pelatihan pada model dan menjalankan prediksi terhadap data baru, dan yang terakhir melakukan evaluasi terhadap model tersebut.

# %% [markdown]
# <h1>Soal 2: Pemahaman Machine Learning</h1>
#
# Pelajarilah secara garis besar suatu model/algoritma machine learning, kemudian aplikasikan untuk membuat model bagi data (variable x, y) di bawah ini. Kemudian buatlah prediksi terhadap data training dan data baru di interval 20-30.
#
# - Plot data asli, data hasil prediksi terhadap data training, data hasil prediksi terhadap data baru
# - Tunjukan beberapa parameter yang dimiliki model yang telah kalian buat

# %%
import matplotlib.pyplot as plt
import numpy as np

rng = np.random.RandomState(42)
x = 20 * rng.rand(50)
y = x**2 + 2 * x + - 1 + rng.randn(50)

# data yang akan di prediksi
x_new = np.arange(20, 30, 0.5)

fig, ax = plt.subplots(figsize=(12, 6))
ax.scatter(x, y)
ax.set_xlabel('X-Value')
ax.set_ylabel('Y-Value')
plt.show()

# %% [markdown]
# Contoh jawaban hasil pembuatan model dengan algoritma DecisionTreeRegressor (jawaban tidak harus sama):
#
# ![alt text](https://drive.google.com/uc?id=1R0mGnMp3DqEsHDiH2_IL4XSS2Roew0wo)

# %% [markdown]
# Contoh jawaban parameters (tidak harus sama):
#
# - Feature Importance : array([1.])
# - n features : 1
#
# Tree Graph :
#
# ![alt text](https://drive.google.com/uc?id=1GM0ba_qjm_e5oLhE9v6pVt2uRBBW6FH9)

# %%
# Code here
#pakai model regressor
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor(max_depth = 5, min_samples_leaf = 5, min_samples_split = 5)

x_matriks = x[:, np.newaxis]

model.fit(x_matriks, y)

x_test = x_new[:, np.newaxis]
y_test = model.predict(x_test)
y_train = model.predict(x_matriks)

# %%
fix,ax = plt.subplots(figsize = (10,5))
ax.scatter(x,y, label = 'Data Asli', color = 'blue')
ax.scatter(x,y_train, label = 'Prediksi terhadap data training', color = 'yellow')
ax.plot(x_test,y_test, label = 'Prediksi terhadap data baru', color = 'green')

ax.set_xlabel('X-Value')
ax.set_ylabel('Y-Value')
plt.legend(loc = 'upper left')
plt.show()

# %%
from sklearn import tree

clf = DecisionTreeRegressor(max_depth = 4, min_samples_leaf = 6, min_samples_split = 6)
tree.plot_tree(clf.fit(x_matriks,y))
# Out:
# [Text(209.25000000000003, 195.696, 'X[0] <= 12.744\nmse = 15993.388\nsamples = 50\nvalue = 129.087'),
#  Text(139.5, 152.208, 'X[0] <= 8.065\nmse = 3370.867\nsamples = 37\nvalue = 64.087'),
#  Text(83.7, 108.72, 'X[0] <= 4.711\nmse = 424.568\nsamples = 24\nvalue = 25.148'),
#  Text(55.800000000000004, 65.232, 'X[0] <= 2.615\nmse = 72.147\nsamples = 16\nvalue = 12.186'),
#  Text(27.900000000000002, 21.744, 'mse = 9.288\nsamples = 7\nvalue = 3.605'),
#  Text(83.7, 21.744, 'mse = 19.206\nsamples = 9\nvalue = 18.861'),
#  Text(111.60000000000001, 65.232, 'mse = 121.393\nsamples = 8\nvalue = 51.071'),
#  Text(195.3, 108.72, 'X[0] <= 10.715\nmse = 843.286\nsamples = 13\nvalue = 135.974'),
#  Text(167.4, 65.232, 'mse = 251.248\nsamples = 7\nvalue = 112.335'),
#  Text(223.20000000000002, 65.232, 'mse = 121.556\nsamples = 6\nvalue = 163.552'),
#  Text(279.0, 152.208, 'X[0] <= 16.986\nmse = 5668.677\nsamples = 13\nvalue = 314.088'),
# ...
